# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/SWQ'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive')
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))
# Out:
# Mounted at /content/gdrive
# ['addressbook.csv', 'addressbook.gsheet', 'addressbook3.csv', 'confusion_matrix.csv', 'data', 'docs', 'evaluation_details.csv', 'mlruns', 'notebooks', 'src', 'test']

# %% [markdown]
# # Imports

# %%
from sklearn.metrics import precision_recall_fscore_support
import numpy as np
import pandas as pd

# %% [markdown]
# # Calc base F1 Score

# %%
states = pd.read_csv('data/SS.csv')

# %%
states["pred"] = 2

# %%
states = states.loc[states['appname'] == "addressbook"]
states
# Out:
#           appname                    crawl    state1    state2  DOM_RTED  \
# 0     addressbook  crawl-addressbook-60min     index    state3  0.214286
# 1     addressbook  crawl-addressbook-60min     index    state5  0.622449
# 2     addressbook  crawl-addressbook-60min     index    state6  0.618182
# 3     addressbook  crawl-addressbook-60min     index    state8  0.240000
# 4     addressbook  crawl-addressbook-60min     index   state10  0.534722
# ...           ...                      ...       ...       ...       ...
# 8510  addressbook  crawl-addressbook-60min  state718  state724  0.019112
# 8511  addressbook  crawl-addressbook-60min  state718  state727  0.028397
# 8512  addressbook  crawl-addressbook-60min  state721  state724  0.009466
# 8513  addressbook  crawl-addressbook-60min  state721  state727  0.018754
# 8514  addressbook  crawl-addressbook-60min  state724  state727  0.009290
#
#       DOM_Levenshtein  DOM_contentHash  DOM_SIMHASH  VISUAL_BlockHash  \
# ...

# %%
precision, recall, fbeta_score, support = precision_recall_fscore_support(states["HUMAN_CLASSIFICATION"], states["pred"], average='weighted', zero_division=1)
print(f"precision: {precision} recall: {recall} f1: {fbeta_score}")
# Out:
# precision: 0.7989804734762218 recall: 0.7213153258954785 f1: 0.604532814580068
